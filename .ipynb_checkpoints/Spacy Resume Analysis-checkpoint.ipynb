# %% [markdown]
# # Spacy Resume Analysis

# %%
#spacy
import spacy
from spacy.pipeline import EntityRuler
from spacy.lang.en import English
from spacy.tokens import Doc

#gensim
import gensim
from gensim import corpora

#Visualization
from spacy import displacy
import pyLDAvis.gensim_models
from wordcloud import WordCloud
import plotly.express as px
import matplotlib.pyplot as plt

#Data loading/ Data manipulation
import pandas as pd
import numpy as np
import jsonlines

#nltk
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download(['stopwords','wordnet'])

#warning
import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv("data/Resume/Resume.csv")
df = df.reindex(np.random.permutation(df.index))
data = df.copy().iloc[0:200,]
data.head()
# Out:
#             ID                                         Resume_str  \
# 1437  10588874           MANAGER AND EXECUTIVE CHEF           ...
# 1900  24703009         STAFF ACCOUNTANT          Virginia    F...
# 804   67032711           FITNESS INSTRUCTOR       Summary    I...
# 516   37333719           SEXUAL ASSAULT CRISIS COUNSELOR / VIC...
# 685   96260484           HEALTHCARE CONSULTANT           Execu...
#
#                                             Resume_html    Category
# 1437  <div class="fontsize fontface vmargins hmargin...        CHEF
# 1900  <div class="fontsize fontface vmargins hmargin...  ACCOUNTANT
# 804   <div class="fontsize fontface vmargins hmargin...     FITNESS
# 516   <div class="fontsize fontface vmargins hmargin...    ADVOCATE
# 685   <div class="fontsize fontface vmargins hmargin...  HEALTHCARE

# %%
# spacy.cli.download('en_core_web_lg')
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
nlp = spacy.load('en_core_web_lg')
skill_pattern_path = "data/jz_skill_patterns.jsonl"

# %%
ruler = nlp.add_pipe('entity_ruler', before='ner')
ruler.from_disk(skill_pattern_path)

patterns = [
    {
        "label": "EMAIL", "pattern": [{"TEXT": {"REGEX": "([^@|\s]+@[^@]+\.[^@|\s]+)"}}]
    },
    {
        "label": "MOBILE", "pattern": [{"TEXT": {"REGEX": "\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4}"}}]
    }
]
# nlp.remove_pipe('entity_ruler')
ruler.add_patterns(patterns)
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'entity_ruler',
#  'ner']

# %%
from spacy import displacy
doc = nlp(data['Resume_str'][685])
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HEALTHCARE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  CONSULTANT           Executive Profile    seminars and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#   media interviews, executive health/longevity expert and corporate wellness consultant. Created award-winning preventive care/patient education center in Family Medicine Residency. Developed residential wellness program at world-renowned
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cooper Clinic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dallas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from ground floor. Administered $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     800,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kellogg Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  grant to train physicians for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Public Health and Preventive Medicine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Developed innovative nutritional system to rank high nutrient-density foods and motivate individuals to simple healthy eating. Designs for Wellness consulting with corporate executives, medical groups, hospitals, wellness centers, nutritional supplement manufacturers. Designed extensive
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     marketing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  strategies for health/wellness publications, healthy food products, and nutritional supplements. Personal Objectives My career goal is to utilize my experience and skills in a larger organization, work with teams to create innovative products and services in health promotion, disease prevention/management, and human longevity fields.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Collaboration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  with diverse groups to synergize process of product development and implementation of patient/client services.       Skill Highlights
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Business
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Development Strategy: Expert  Product
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marketing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Strategy: Expert  Operational Systems Efficiency: Expert  Wellness Program Development: Expert  Lifestyle Change Methodology: Expert                Professional Experience      Healthcare Consultant
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#    to   Current     Company Name   －   City  ,   State      Specializes in assisting physicians, hospitals, outpatient rehabilitation clinics, and a diverse list of other healthcare providers throughout the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   and abroad to achieve their strategic and operational goals.          President and Founder
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1990
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#    to   Current     Company Name   －   City  ,   State      Responsible for overall strategy and implementation of all aspects of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     business
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# .  Company provides consulting and training seminars in the areas of executive health, corporate wellness, nutrition, stress management/work-life balance, fitness, and longevity.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Publishing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  in the areas of nutrition, fitness, wellness, sports, and spiritual development.          Executive Director
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1984
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#    to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1990
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#      Company Name   －   City  ,   State      Developed residential
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cooper Wellness Program
#     <span style="font-size: 0.8em; font-weight: bold; lin

# %%
displacy.render(doc[0:10], style="dep", jupyter=True, options={"distance": 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ad4db64ea23e409cacc05c049d9d049d-0" class="displacy" width="950" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">         </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">HEALTHCARE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">CONSULTANT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">          </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Executive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Profile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">seminars</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">200</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ad4db64ea23e409cacc05c049d9d049d-0-0" stroke-width="2px" d="M70,182.0 C70,2.0 500.0,2.0 500.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ad4db64ea23e409cacc05c049d9d049d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ad4db64ea23e409cacc05c049d9d049d-0-1" stroke-width="2px" d="M160,182.0 C160,137.0 215.0,137.0 215.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ad4db64ea23e409cacc05c049d9d049d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,184.0 L152,172.0 168,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ad4db64ea23e409cacc05c049d9d049d-0-2" stroke-width="2px" d="M250,182.0 C250,47.0 495.0,47.0 495.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ad4db64ea23e409cacc05c049d9d049d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,184.0 L242,172.0 258,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ad4db64ea23e409cacc05c049d9d049d-0-3" stroke-width="2px" d="M340,182.0 C340,92.0 490.0,92.0 490.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ad4db64ea23e409cacc05c049d9d049d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340,184.0 L332,172.0 348,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ad4db64ea23e409cacc05c049d9d049d-0-4" stroke-width="2px" d="M430,182.0 C430,137.0 485.0,137.0 485.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ad4db64ea23e409cacc05c049d9d049d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ad4db64ea23e409cacc05c049d9d049d-0-5" stroke-width="2px" d="M520,182.0 C520,137.0 575.0,137.0 575.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ad4db64ea23e409cacc05c049d9d049d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520,184.0 L512,172.0 528,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ad4db64ea23e409cacc05c049d9d049d-0-6" stroke-width="2px" d="M610,182.0 C610,137.0 665.0,137.0 665.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ad4db64ea23e409cacc05c049d9d049d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610,184.0 L602,172.0 618,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ad4db64ea23e409cacc05c049d9d049d-0-7" stroke-width="2px" d="M700,182.0 C700,137.0 755.0,137.0 755.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ad4db64ea23e409cacc05c049d9d049d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M755.0,184.0 L763.0,172.0 747.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ad4db64ea23e409cacc05c049d9d049d-0-8" stroke-width="2px" d="M700,182.0 C700,92.0 850.0,92.0 850.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ad4db64ea23e409cacc05c049d9d049d-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M850.0,184.0 L858.0,172.0

# %%
text = "My name is Subhradeep Rang. I have a good knowledge on Data Science and Machine Learning. I also know Python, C++, Kotlin. My Email Address is srang992@gmail.com"
doc2 = nlp(text)
displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">My name is
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Subhradeep Rang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# . I have a good knowledge on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data Science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Machine Learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# . I also know
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kotlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# . My Email Address is
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     srang992@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EMAIL</span>
# </mark>
# </div></span>

# %%
patterns = df.Category.unique()
for a in patterns:
    ruler.add_patterns([{"label": "Job-Category", "pattern": a}])

# %%
pattern2 = [
    {
        "label": "PERSON", "pattern": [{"LOWER": "subhradeep"}, {"LOWER": "rang"}]
    },
    {
        "label": "PERSON", "pattern": [{"LOWER": "tanuja"}, {"LOWER": "rang"}]
    },
    {
        "label": "ORG", "pattern": [{"LOWER": "maulana"},{"LOWER": "abul"}, {"LOWER": "kalam"}, {"LOWER": "azad"},
                                    {"LOWER": "university"}, {"LOWER": "of"}, {"LOWER": "technology"}]
    },
    {
        "label": "GPE", "pattern": [{"LOWER": "Hooghly"}]
    },
    {
        "label": "Job-Category", "pattern":[{"TEXT": "DIGITAL"}, {"LOWER": "MARKETING"}, {"LOWER": "DIRECTOR"}]
    }
]

ruler.add_patterns(pattern2)

# %%
text2 = "My name is Subhradeep Rang. \
I live in Konnagar, Hooghly. I am persuing M.Sc. in Artificial Intelligence from Maulana Abul Kalam Azad University \
of Technology. I know Python, Kotlin, C, C++, Java. I have a good  knowledge on Data Science and Machine Learning Domain. \
My email address is srang992@gmail.com."

doc3 = nlp(text2)
displacy.render(doc3, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">My name is
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Subhradeep Rang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . I live in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Konnagar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hooghly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . I am persuing M.Sc. in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artificial Intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maulana Abul Kalam Azad University of Technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . I know
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kotlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# . I have a good  knowledge on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data Science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Machine Learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Domain. My email address is
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     srang992@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EMAIL</span>
# </mark>
# .</div></span>

# %%
# options=[{"ents": "Job-Category", "colors": "#ff3232"},{"ents": "SKILL", "colors": "#56c426"}]
colors = {
    "Job-Category": "linear-gradient(90deg, #aa9cfc, #fc9ce7)",
    "SKILL": "linear-gradient(90deg, #9BE15D, #00E3AE)",
    "ORG": "#ffd966",
    "PERSON": "#e06666",
    "GPE": "#9fc5e8",
    "DATE": "#c27ba0",
    "ORDINAL": "#674ea7",
    "PRODUCT": "#f9cb9c",
}
options = {
    "ents": [
        "Job-Category",
        "SKILL",
        "ORG",
        "PERSON",
        "GPE",
        "DATE",
        "ORDINAL",
        "PRODUCT",
    ],
    "colors": colors,
}
sent = nlp(data["Resume_str"].iloc[6])
displacy.render(sent, style="ent", jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DIGITAL MARKETING DIRECTOR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Job-Category</span>
# </mark>
#            Summary    With a background in
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marketing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and Event production, I extend my passion for exploiting new ways to enhance communication and networking actions to manage
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     business
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  processes more effectively, and engaging in active dialogues with global clients. International
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marketing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  development and Event production is my preference for hiring. While working in a multi cultural environments, I believe diversity has a great impact on a company's growth and success. I am interested in joining a company where I can contribute in a variety of ways leveraging my background within innovation tech, entrepreneurship funding  as well as my
# <mark class="entity" style="background: #674ea7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -hand experiences working  producing  events for the benefit of networking. The degree was designed to give a broad knowledge of the functional areas of a company, and their
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     interconnection
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , while also allowing for specialization in a particular area. Experienced a variety of &quot;core subjects and allowing me to specialize in administration as the selective specific academic area. The degree also developed my practical managerial skills, communication skills and
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     business
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  decision-making capability. Excelled in classes with practical experience, in the form of case projects, presentations, industrial visits, and
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     interaction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  with experts from the industry.</br>Volunteer work(  events)          </br>Ambassador for a Danish networking event called
# <mark class="entity" style="background: #ffd966; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DABGO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Its a Danish networking group focused on all the sharing the social aspects of life  and the
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     business
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  functionalities. Local can connect and network once
# <mark class="entity" style="background: #c27ba0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The group attracted Silicon Valley residents with the average of 30 participants.  This event takes place in 30 countries worldwide, on the exact
# <mark class="entity" style="background: #c27ba0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     same day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , yet once a year I produced the overall event far all our 200 ambassadors.      Highlights        Excellent Microsoft Office skills,
# <mark class="entity" style="background: #ffd966; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     QuickBooks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffd966; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Navision
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffd966; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rejs Ud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (Danish government
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     software
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ), basic
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HTML
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Keynote,
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CSS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  suite, Coding and Web
# <mark class="entity" style="background: linear-gradient(90deg, #9BE15D, #00E3AE); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     design
#     <span style="font-size: 0.8em;

# %%
doc = sent = nlp(data["Resume_str"][685])
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HEALTHCARE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Job-Category</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CONSULTANT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Job-Category</span>
# </mark>
#            Executive Profile    seminars and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#   media interviews, executive health/longevity expert and corporate wellness consultant. Created award-winning preventive care/patient education center in Family Medicine Residency. Developed residential wellness program at world-renowned
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cooper Clinic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dallas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from ground floor. Administered $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     800,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kellogg Foundation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  grant to train physicians for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Public Health and Preventive Medicine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Developed innovative nutritional system to rank high nutrient-density foods and motivate individuals to simple healthy eating. Designs for Wellness consulting with corporate executives, medical groups, hospitals, wellness centers, nutritional supplement manufacturers. Designed extensive
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     marketing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  strategies for health/wellness publications, healthy food products, and nutritional supplements. Personal Objectives My career goal is to utilize my experience and skills in a larger organization, work with teams to create innovative products and services in health promotion, disease prevention/management, and human longevity fields.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Collaboration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  with diverse groups to synergize process of product development and implementation of patient/client services.       Skill Highlights
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Business
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Development Strategy: Expert  Product
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marketing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Strategy: Expert  Operational Systems Efficiency: Expert  Wellness Program Development: Expert  Lifestyle Change Methodology: Expert                Professional Experience      Healthcare Consultant
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#    to   Current     Company Name   －   City  ,   State      Specializes in assisting physicians, hospitals, outpatient rehabilitation clinics, and a diverse list of other healthcare providers throughout the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   and abroad to achieve their strategic and operational goals.          President and Founder
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1990
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#    to   Current     Company Name   －   City  ,   State      Responsible for overall strategy and implementation of all aspects of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     business
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# .  Company provides consulting and training seminars in the areas of executive health, corporate wellness, nutrition, stress management/work-life balance, fitness, and longevity.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Publishing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  in the areas of nutrition, fitness, wellness, sports, and spiritual development.          Executive Director
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1984
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#    to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1990
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem

# %%
# class ProcessSkills:
#
#     @staticmethod
#     def get_skills(text):
#         doc = nlp(text)
#         myset = []
#         subset = []
#         for ent in doc.ents:
#             if ent.label_ == "SKILL":
#                 subset.append(ent.text)
#         myset.append(subset)
#         return subset
#
#     @staticmethod
#     def unique_skills(x):
#         return list(set(x))

# %%
# nltk.download('omw-1.4')

# %%
# clean = []
# for i in range(data.shape[0]):
#     review = re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?"', " ",data["Resume_str"].iloc[i],)
#     review = review.lower()
#     review = review.split()
#     lm = WordNetLemmatizer()
#     review = [
#         lm.lemmatize(word)
#         for word in review
#         if not word in set(stopwords.words("english"))
#     ]
#     review = " ".join(review)
#     clean.append(review)

# %%
# data['clean_resume'] = clean
# data['skills'] = data['clean_resume'].str.lower().apply(ProcessSkills().get_skills)
# data['skills'] = data['skills'].apply(ProcessSkills().unique_skills)
# data.head()

# %%
# !pip install -qq pyresparser

# %%
# !pip install python-docx docx
# Out:
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting docx
#   Downloading docx-0.2.4.tar.gz (54 kB)
#      ---------------------------------------- 54.9/54.9 KB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting lxml>=2.3.2
#   Using cached lxml-4.8.0-cp37-cp37m-win_amd64.whl (3.6 MB)
# Requirement already satisfied: Pillow>=2.0 in d:\spacy resume analysis\resume_venv\lib\site-packages (from docx) (9.0.1)
# Building wheels for collected packages: python-docx, docx
#   Building wheel for python-docx (setup.py): started
#   Building wheel for python-docx (setup.py): finished with status 'done'
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=ddfe88404480bd62d26973abe1b3e1381f7122a97066ca21a90661840d548c03
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\f6\6f\b9\d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
#   Building wheel for docx (setup.py): started
#   Building wheel for docx (setup.py): finished with status 'done'
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53924 sha256=704eca7ca945e457f795fa0c845a52664f246e4f21c24ff3571d5b9744b10b61
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\dc\ac\45\846e21706415c92fc6e0964e343be1eb31cfc63e149dee5fbe
# Successfully built python-docx docx
# Installing collected packages: lxml, python-docx, docx
# Successfully installed docx-0.2.4 lxml-4.8.0 python-docx-0.8.11

# %%
spacy.cli.download('en_core_web_sm')
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from docx import Document
from pyresparser import ResumeParser

try:
    doc = Document()
    with open("C:/Users/HP/Downloads/Subhradeep Rang's Resume Now.pdf", 'r') as file:
        doc.add_paragraph(file.read())
    doc.save("text.docx")
    data = ResumeParser('text.docx').get_extracted_data()
    print(data['skills'])
except:
    data = ResumeParser("C:/Users/HP/Downloads/Subhradeep Rang's Resume Now.pdf").get_extracted_data()
    print(data['skills'])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14840\2133486527.py in <module>
#       6     with open("C:/Users/HP/Downloads/Subhradeep Rang's Resume Now.pdf", 'r') as file:
# ----> 7         doc.add_paragraph(file.read())
#       8     doc.save("text.docx")
#
# ~\AppData\Local\Programs\Python\Python37\lib\encodings\cp1252.py in decode(self, input, final)
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 1934: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14840\2133486527.py in <module>
#      10     print(data['skills'])
#      11 except:
# ---> 12     data = ResumeParser("C:/Users/HP/Downloads/Subhradeep Rang's Resume Now.pdf").get_extracted_data()
#      13     print(data['skills'])
#
# D:\spacy resume analysis\resume_venv\lib\site-packages\pyresparser\resume_parser.py in __init__(self, resume, skills_file, custom_regex)
#      19     ):
#      20         nlp = spacy.load('en_core_web_sm')
# ---> 21         custom_nlp = spacy.load(os.path.dirname(os.path.abspath(__file__)))
#      22         self.__skills_file = skills_file
#      23         self.__custom_regex = custom_regex
#
# D:\spacy resume analysis\resume_venv\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, exclude, config)
#      50     """
#      51     return util.load_model(
# ---> 52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#      54
#
# D:\spacy resume analysis\resume_venv\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     420             return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     421         if Path(name).exists():  # path to model data directory
# --> 422             return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#     423     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     424         return load_model_from_path(name, **kwargs)  # type: ignore[arg-type]
#
# D:\spacy resume analysis\resume_venv\lib\site-packages\spacy\util.py in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     485     config_path = model_path / "config.cfg"
#     486     overrides = dict_to_dot(config)
# --> 487     config = load_config(config_path, overrides=overrides)
#     488     nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
#     489     return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# D:\spacy resume analysis\resume_venv\lib\site-packages\spacy\util.py in load_config(path, overrides, interpolate)
#     644     else:
#     645         if not config_path or not config_path.is_file():
# --> 646             raise IOError(Errors.E053.format(path=config_path, name="config file"))
#     647         return config.from_disk(
#     648             config_path, overrides=overrides, interpolate=interpolate
#
# OSError: [E053] Could not read config file from D:\spacy resume analysis\resume_venv\lib\site-packages\pyresparser\config.cfg
